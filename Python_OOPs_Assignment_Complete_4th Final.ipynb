# %% [markdown]
# # Python OOPs Assignment

# %%
# Q1. What is Object-Oriented Programming (OOP)?
# OOP organizes code into classes and objects. Example: Car class creates car objects.

# %%
# Q2. What is a class in OOP?
# A class is a blueprint for creating objects. Example: class Student.

# %%
# Q3. What is an object in OOP?
# An object is an instance of a class. Example: s=Student().

# %%
# Q4. What is the difference between abstraction and encapsulation?
# Abstraction hides implementation; encapsulation protects data. Example: ATM hides logic; private balance.

# %%
# Q5. What are dunder methods in Python?
# Dunder methods are special methods like __init__. Example: __str__.

# %%
# Q6. Explain the concept of inheritance in OOP.
# Inheritance lets one class reuse another. Example: Dog inherits Animal.

# %%
# Q7. What is polymorphism in OOP?
# Polymorphism allows same method name with different behavior. Example: speak().

# %%
# Q8. How is encapsulation achieved in Python?
# Using private members and getter/setter methods. Example: __balance.

# %%
# Q9. What is a constructor in Python?
# Constructor (__init__) initializes objects. Example: Person('Ram').

# %%
# Q10. What are class and static methods in Python?
# Class methods use cls; static methods need neither cls nor self.

# %%
# Q11. What is method overloading in Python?
# Python simulates overloading using default/*args. Example: add(*nums).

# %%
# Q12. What is method overriding in OOP?
# Overriding replaces parent method in child. Example: Dog.speak().

# %%
# Q13. What is a property decorator in Python?
# @property lets methods act like attributes. Example: obj.age.

# %%
# Q14. Why is polymorphism important in OOP?
# It improves flexibility and reusable code. Example: different shapes area().

# %%
# Q15. What is an abstract class in Python?
# Abstract class cannot be instantiated directly. Example: ABC Shape.

# %%
# Q16. What are the advantages of OOP?
# OOP improves reuse, maintenance and security.

# %%
# Q17. What is the difference between a class variable and an instance variable?
# Class variables are shared; instance variables belong to each object.

# %%
# Q18. What is multiple inheritance in Python?
# Multiple inheritance means inheriting from more than one parent class.

# %%
# Q19. Explain the purpose of '__str__' and '__repr__' methods in Python.
# __str__ is user-friendly; __repr__ is developer-friendly.

# %%
# Q20. What is the significance of the super() function in Python?
# super() calls parent class methods/constructor.

# %%
# Q21. What is the significance of the __del__ method in Python?
# __del__ runs when object is destroyed.

# %%
# Q22. What is the difference between @staticmethod and @classmethod in Python?
# @staticmethod has no cls; @classmethod receives cls.

# %%
# Q23. How does polymorphism work in Python with inheritance?
# Child classes override parent methods and are used through parent references.

# %%
# Q24. What is method chaining in Python OOP?
# Method chaining returns self. Example: obj.a().b().

# %%
# Q25. What is the purpose of the __call__ method in Python?
# __call__ lets an object behave like a function.

# %% [markdown]
# ## Practical Question 1

# %%
class Animal:
    def speak(self): print('Animal speaks')
class Dog(Animal):
    def speak(self): print('Bark!')
Dog().speak()
# Out:
# Bark!

# %% [markdown]
# ## Practical Question 2

# %%
from abc import ABC,abstractmethod
class Shape(ABC):
 @abstractmethod
 def area(self):...
class Circle(Shape):
 def __init__(self,r): self.r=r
 def area(self): return 3.14*self.r*self.r
class Rectangle(Shape):
 def __init__(self,l,b): self.l=l;self.b=b
 def area(self): return self.l*self.b
print(Circle(2).area(),Rectangle(2,3).area())
# Out:
# 12.56 6

# %% [markdown]
# ## Practical Question 3

# %%
class Vehicle:
 def __init__(self): self.type='Vehicle'
class Car(Vehicle): pass
class ElectricCar(Car):
 def __init__(self,b): super().__init__(); self.battery=b
print(ElectricCar('60kWh').battery)
# Out:
# 60kWh

# %% [markdown]
# ## Practical Question 4

# %%
class Bird:
 def fly(self): print('Fly')
class Sparrow(Bird):
 def fly(self): print('Sparrow flies')
class Penguin(Bird):
 def fly(self): print('Penguin cannot fly')
for b in [Sparrow(),Penguin()]: b.fly()
# Out:
# Sparrow flies
# Penguin cannot fly

# %% [markdown]
# ## Practical Question 5

# %%
class BankAccount:
 def __init__(self): self.__balance=0
 def deposit(self,a): self.__balance+=a
 def withdraw(self,a): self.__balance-=a
 def check_balance(self): return self.__balance
b=BankAccount(); b.deposit(500); print(b.check_balance())
# Out:
# 500

# %% [markdown]
# ## Practical Question 6

# %%
class Instrument:
 def play(self): pass
class Guitar(Instrument):
 def play(self): print('Guitar')
class Piano(Instrument):
 def play(self): print('Piano')
for i in [Guitar(),Piano()]: i.play()
# Out:
# Guitar
# Piano

# %% [markdown]
# ## Practical Question 7

# %%
class MathOperations:
 @classmethod
 def add_numbers(cls,a,b): return a+b
 @staticmethod
 def subtract_numbers(a,b): return a-b
print(MathOperations.add_numbers(2,3),MathOperations.subtract_numbers(5,2))
# Out:
# 5 3

# %% [markdown]
# ## Practical Question 8

# %%
class Person:
 count=0
 def __init__(self): Person.count+=1
 @classmethod
 def total(cls): return cls.count
Person();Person();print(Person.total())
# Out:
# 2

# %% [markdown]
# ## Practical Question 9

# %%
class Fraction:
 def __init__(self,n,d): self.n=n;self.d=d
 def __str__(self): return f'{self.n}/{self.d}'
print(Fraction(1,2))
# Out:
# 1/2

# %% [markdown]
# ## Practical Question 10

# %%
class Vector:
 def __init__(self,x,y): self.x=x;self.y=y
 def __add__(self,o): return Vector(self.x+o.x,self.y+o.y)
 def __str__(self): return f'({self.x},{self.y})'
print(Vector(1,2)+Vector(3,4))
# Out:
# (4,6)

# %% [markdown]
# ## Practical Question 11

# %%
class Person:
 def __init__(self,n,a): self.n=n;self.a=a
 def greet(self): print(f'Hello, my name is {self.n} and I am {self.a} years old.')
Person('Ram',20).greet()
# Out:
# Hello, my name is Ram and I am 20 years old.

# %% [markdown]
# ## Practical Question 12

# %%
class Student:
 def __init__(self,n,g): self.g=g
 def average_grade(self): return sum(self.g)/len(self.g)
print(Student('A',[80,90]).average_grade())
# Out:
# 85.0

# %% [markdown]
# ## Practical Question 13

# %%
class Rectangle:
 def set_dimensions(self,l,b): self.l=l;self.b=b
 def area(self): return self.l*self.b
r=Rectangle();r.set_dimensions(4,5);print(r.area())
# Out:
# 20

# %% [markdown]
# ## Practical Question 14

# %%
class Employee:
 def calculate_salary(self,h,r): return h*r
class Manager(Employee):
 def calculate_salary(self,h,r): return super().calculate_salary(h,r)+1000
print(Manager().calculate_salary(10,100))
# Out:
# 2000

# %% [markdown]
# ## Practical Question 15

# %%
class Product:
 def __init__(self,n,p,q): self.p=p;self.q=q
 def total_price(self): return self.p*self.q
print(Product('Pen',10,5).total_price())
# Out:
# 50

# %% [markdown]
# ## Practical Question 16

# %%
from abc import ABC,abstractmethod
class Animal(ABC):
 @abstractmethod
 def sound(self):...
class Cow(Animal):
 def sound(self): print('Moo')
class Sheep(Animal):
 def sound(self): print('Baa')
Cow().sound();Sheep().sound()
# Out:
# Moo
# Baa

# %% [markdown]
# ## Practical Question 17

# %%
class Book:
 def __init__(self,t,a,y): self.t=t;self.a=a;self.y=y
 def get_book_info(self): return f'{self.t} by {self.a} ({self.y})'
print(Book('Python','Guido',2024).get_book_info())
# Out:
# Python by Guido (2024)

# %% [markdown]
# ## Practical Question 18

# %%
class House:
 def __init__(self,a,p): self.address=a;self.price=p
class Mansion(House):
 def __init__(self,a,p,r): super().__init__(a,p); self.number_of_rooms=r
m=Mansion('Lucknow',1000000,10);print(m.number_of_rooms)
# Out:
# 10
